# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tmdb_movies_data.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                                 homepage            director  \
# 0                          http://www.jurassicworld.com/     Colin Trevorrow
# 1                            http://www.madmaxmovie.com/       George Miller
# 2         http://www.thedivergentseries.movie/#insurgent    Robert Schwentke
# 3      http://www.starwars.com/films/star-wars-episod...         J.J. Abrams
# 4                               http://www.furious7.com/           James Wan
# ...                                                  ...                 ...
# 10861                                                NaN         Bruce Brown
# 10862                                                NaN  John Frankenheimer
# 10863                                                NaN      Eldar Ryazanov
# 10864                                                NaN         Woody Allen
# 10865                                                NaN    Harold P. Warren
#
#                                                  tagline  ...  \
# 0                                      The park is open.  ...
# 1                                     What a Lovely Day.  ...
# 2                             One Choice Can Destroy You  ...
# 3                          Every generation has a story.  ...
# 4                                    Vengeance Hits Home  ...
# ...                                                  ...  ...
# 10861                                                NaN  ...
# 10862  Cinerama sweeps YOU into a drama of speed and ...  ...
# 10863                                                NaN  ...
# 10864                          WOODY ALLEN STRIKES BACK!  ...
# 10865       It's Shocking! It's Beyond Your Imagination!  ...
#
#                                                 overview runtime  \
# 0      Twenty-two years after the events of Jurassic ...     124
# 1      An apocalyptic story set in the furthest reach...     120
# 2      Beatrice Prior must confront her inner demons ...     119
# 3      Thirty years after defeating the Galactic Empi...     136
# 4      Deckard Shaw seeks revenge against Dominic Tor...     137
# ...                                                  ...     ...
# 10861  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  An insurance agent who moonlights as a carthie...      94
# 10864  In comic Woody Allen's film debut, he took the...      80
# 10865  A family gets lost on the road and stumbles up...      74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0           5562           6.5          2015  1.379999e+08  1.392446e+09
# 1           6185           7.1          2015  1.379999e+08  3.481613e+08
# 2           2480           6.3          2015  1.012000e+08  2.716190e+08
# 3           5292           7.5          2015  1.839999e+08  1.902723e+09
# 4           2947           7.3          2015  1.747999e+08  1.385749e+09
# ...          ...           ...           ...           ...           ...
# 10861         11           7.4          1966  0.000000e+00  0.000000e+00
# 10862         20           5.7          1966  0.000000e+00  0.000000e+00
# 10863         11           6.5          1966  0.000000e+00  0.000000e+00
# 10864         22           5.4          1966  0.000000e+00  0.000000e+00
# 10865         15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10866 rows x 21 columns]

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.drop('homepage',inplace=True,axis=1)

# %%
df[['budget','revenue']].corr()
# Out:
#            budget   revenue
# budget   1.000000  0.734901
# revenue  0.734901  1.000000

# %%
df.drop(['budget_adj','revenue_adj','overview','imdb_id','tagline'],axis =1,inplace = True)

# %%
df
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10861      21    0.080598          0           0
# 10862   20379    0.065543          0           0
# 10863   39768    0.065141          0           0
# 10864   21449    0.064317          0           0
# 10865   22293    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...                             ...
# 10861            The Endless Summer
# 10862                    Grand Prix
# 10863           Beregis Avtomobilya
# 10864        What's Up, Tiger Lily?
# 10865      Manos: The Hands of Fate
#
#                                                     cast            director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...     Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...       George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...    Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...         J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...           James Wan
# ...                                                  ...                 ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#                                                 keywords  runtime  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1       future|chase|post-apocalyptic|dystopia|australia      120
# 2      based on novel|revolution|dystopia|sequel|dyst...      119
# 3                  android|spaceship|jedi|space opera|3d      136
# 4                    car race|speed|revenge|suspense|car      137
# ...                                                  ...      ...
# 10861                           surfer|surfboard|surfing       95
# 10862                          car race|racing|formula 1      176
# 10863                           car|trolley|stealing car       94
# 10864                                              spoof       80
# 10865                fire|gun|drive|sacrifice|flashlight       74
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# 3       Action|Adventure|Science Fiction|Fantasy
# 4                          Action|Crime|Thriller
# ...                                          ...
# 10861                                Documentary
# 10862                     Action|Adventure|Drama
# 10863                             Mystery|Comedy
# 10864                              Action|Comedy
# 10865                                     Horror
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#        vote_count  vote_average  release_year
# 0            5562           6.5          2015
# 1            6185           7.1          2015
# 2            2480           6.3          2015
# 3            5292           7.5          2015
# 4            2947           7.3          2015
# ...           ...           ...           ...
# 10861          11           7.4          1966
# 10862          20           5.7          1966
# 10863          11           6.5          1966
# 10864          22           5.4          1966
# 10865          15           1.5          1966
#
# [10866 rows x 15 columns]

# %%
movie = df.copy(deep=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
movie['genres'] = enc.fit_transform(movie['genres'].values)

# %%
movie[['genres','popularity']].corr()
# Out:
#               genres  popularity
# genres      1.000000   -0.072767
# popularity -0.072767    1.000000

# %%
movie
# Out:
#            id  popularity       budget       revenue  \
# 0      135397   32.985763  150000000.0  1.513529e+09
# 1       76341   28.419936  150000000.0  3.784364e+08
# 2      262500   13.112507  110000000.0  2.952382e+08
# 3      140607   11.173104  200000000.0  2.068178e+09
# 4      168259    9.335014  190000000.0  1.506249e+09
# ...       ...         ...          ...           ...
# 10822     396    0.670274    7500000.0  3.373669e+07
# 10828    5780    0.402730    3000000.0  1.300000e+07
# 10829    6644    0.395668    4653000.0  6.000000e+06
# 10835    5923    0.299911   12000000.0  2.000000e+07
# 10848    2161    0.207257    5115000.0  1.200000e+07
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...                                ...
# 10822  Who's Afraid of Virginia Woolf?
# 10828                     Torn Curtain
# 10829                        El Dorado
# 10835                 The Sand Pebbles
# 10848                 Fantastic Voyage
#
#                                                     cast           director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...    Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...   Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...        J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...          James Wan
# ...                                                  ...                ...
# 10822  Elizabeth Taylor|Richard Burton|George Segal|S...       Mike Nichols
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|Hansj̦...   Alfred Hitchcock
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...       Howard Hawks
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...        Robert Wise
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...  Richard Fleischer
#
#                                                 keywords  runtime  genres  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island    124.0      73
# 1       future|chase|post-apocalyptic|dystopia|australia    120.0      73
# 2      based on novel|revolution|dystopia|sequel|dyst...    119.0     338
# 3                  android|spaceship|jedi|space opera|3d    136.0      72
# 4                    car race|speed|revenge|suspense|car    137.0     130
# ...                                                  ...      ...     ...
# 10822      alcohol|adultery|professor|married couple|son    131.0     530
# 10828                              cold war|east germany    128.0     849
# 10829              sheriff|ranch|liquor|settler|revolver    120.0     213
# 10835            missionary|china|us navy|chinese|battle    182.0      51
# 10848          submarine|coma|claustrophobia|wound|laser    100.0     335
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10822                               Chenault Productions    6/21/1966
# 10828                                 Universal Pictures    7/13/1966
# 10829              Paramount Pictures|Laurel Productions   12/17/1966
# 10835  Twentieth Century Fox Film Corporation|Solar P...   12/20/1966
# 10848             Twentieth Century Fox Film Corporation    8/24/1966
#
#        vote_count  vote_average  release_year
# 0            5562           6.5          2015
# 1            6185           7.1          2015
# 2            2480           6.3          2015
# 3            5292           7.5          2015
# 4            2947           7.3          2015
# ...           ...           ...           ...
# 10822          74           7.5          1966
# 10828          46           6.3          1966
# 10829          36           6.9          1966
# 10835          28           7.0          1966
# 10848          42           6.7          1966
#
# [3678 rows x 15 columns]

# %%
movie['release_date'] = pd.to_datetime(movie['release_date'])
movie['release_date'].head()
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# Name: release_date, dtype: datetime64[ns]

# %%
from datetime import datetime

# %%
def check_weekday(date):
      
    # computing the parameter date
    # with len function
    res=len(pd.bdate_range(date,date))
      
    if res == 0 :
        return 'weekend'
    else:
        return 'weekday'

# %%
movie['weeknd'] = movie['release_date'].apply(check_weekday)

# %%
movie
# Out:
#            id  popularity       budget       revenue  \
# 0      135397   32.985763  150000000.0  1.513529e+09
# 1       76341   28.419936  150000000.0  3.784364e+08
# 2      262500   13.112507  110000000.0  2.952382e+08
# 3      140607   11.173104  200000000.0  2.068178e+09
# 4      168259    9.335014  190000000.0  1.506249e+09
# ...       ...         ...          ...           ...
# 10822     396    0.670274    7500000.0  3.373669e+07
# 10828    5780    0.402730    3000000.0  1.300000e+07
# 10829    6644    0.395668    4653000.0  6.000000e+06
# 10835    5923    0.299911   12000000.0  2.000000e+07
# 10848    2161    0.207257    5115000.0  1.200000e+07
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...                                ...
# 10822  Who's Afraid of Virginia Woolf?
# 10828                     Torn Curtain
# 10829                        El Dorado
# 10835                 The Sand Pebbles
# 10848                 Fantastic Voyage
#
#                                                     cast           director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...    Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...   Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...        J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...          James Wan
# ...                                                  ...                ...
# 10822  Elizabeth Taylor|Richard Burton|George Segal|S...       Mike Nichols
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|Hansj̦...   Alfred Hitchcock
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...       Howard Hawks
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...        Robert Wise
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...  Richard Fleischer
#
#                                                 keywords  runtime  genres  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island    124.0      73
# 1       future|chase|post-apocalyptic|dystopia|australia    120.0      73
# 2      based on novel|revolution|dystopia|sequel|dyst...    119.0     338
# 3                  android|spaceship|jedi|space opera|3d    136.0      72
# 4                    car race|speed|revenge|suspense|car    137.0     130
# ...                                                  ...      ...     ...
# 10822      alcohol|adultery|professor|married couple|son    131.0     530
# 10828                              cold war|east germany    128.0     849
# 10829              sheriff|ranch|liquor|settler|revolver    120.0     213
# 10835            missionary|china|us navy|chinese|battle    182.0      51
# 10848          submarine|coma|claustrophobia|wound|laser    100.0     335
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1      Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2      Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# 3              Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 4      Universal Pictures|Original Film|Media Rights ...   2015-04-01
# ...                                                  ...          ...
# 10822                               Chenault Productions   1966-06-21
# 10828                                 Universal Pictures   1966-07-13
# 10829              Paramount Pictures|Laurel Productions   1966-12-17
# 10835  Twentieth Century Fox Film Corporation|Solar P...   1966-12-20
# 10848             Twentieth Century Fox Film Corporation   1966-08-24
#
#        vote_count  vote_average  release_year   weeknd
# 0            5562           6.5          2015  weekday
# 1            6185           7.1          2015  weekday
# 2            2480           6.3          2015  weekday
# 3            5292           7.5          2015  weekday
# 4            2947           7.3          2015  weekday
# ...           ...           ...           ...      ...
# 10822          74           7.5          1966  weekday
# 10828          46           6.3          1966  weekday
# 10829          36           6.9          1966  weekend
# 10835          28           7.0          1966  weekday
# 10848          42           6.7          1966  weekday
#
# [3678 rows x 16 columns]

# %%
def friday(date):
    temp = pd.Timestamp(date)
    if temp.day_name()=='Friday':
        return 1
    else:
        return 0

# %%
movie['friday'] = movie['release_date'].apply(friday)

# %%
movie
# Out:
#            id  popularity       budget       revenue  \
# 0      135397   32.985763  150000000.0  1.513529e+09
# 1       76341   28.419936  150000000.0  3.784364e+08
# 2      262500   13.112507  110000000.0  2.952382e+08
# 3      140607   11.173104  200000000.0  2.068178e+09
# 4      168259    9.335014  190000000.0  1.506249e+09
# ...       ...         ...          ...           ...
# 10822     396    0.670274    7500000.0  3.373669e+07
# 10828    5780    0.402730    3000000.0  1.300000e+07
# 10829    6644    0.395668    4653000.0  6.000000e+06
# 10835    5923    0.299911   12000000.0  2.000000e+07
# 10848    2161    0.207257    5115000.0  1.200000e+07
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...                                ...
# 10822  Who's Afraid of Virginia Woolf?
# 10828                     Torn Curtain
# 10829                        El Dorado
# 10835                 The Sand Pebbles
# 10848                 Fantastic Voyage
#
#                                                     cast           director  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...    Colin Trevorrow
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...   Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...        J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...          James Wan
# ...                                                  ...                ...
# 10822  Elizabeth Taylor|Richard Burton|George Segal|S...       Mike Nichols
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|Hansj̦...   Alfred Hitchcock
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...       Howard Hawks
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...        Robert Wise
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...  Richard Fleischer
#
#                                                 keywords  runtime  genres  \
# 0      monster|dna|tyrannosaurus rex|velociraptor|island    124.0      73
# 1       future|chase|post-apocalyptic|dystopia|australia    120.0      73
# 2      based on novel|revolution|dystopia|sequel|dyst...    119.0     338
# 3                  android|spaceship|jedi|space opera|3d    136.0      72
# 4                    car race|speed|revenge|suspense|car    137.0     130
# ...                                                  ...      ...     ...
# 10822      alcohol|adultery|professor|married couple|son    131.0     530
# 10828                              cold war|east germany    128.0     849
# 10829              sheriff|ranch|liquor|settler|revolver    120.0     213
# 10835            missionary|china|us navy|chinese|battle    182.0      51
# 10848          submarine|coma|claustrophobia|wound|laser    100.0     335
#
#                                     production_companies release_date  \
# 0      Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1      Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2      Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# 3              Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 4      Universal Pictures|Original Film|Media Rights ...   2015-04-01
# ...                                                  ...          ...
# 10822                               Chenault Productions   1966-06-21
# 10828                                 Universal Pictures   1966-07-13
# 10829              Paramount Pictures|Laurel Productions   1966-12-17
# 10835  Twentieth Century Fox Film Corporation|Solar P...   1966-12-20
# 10848             Twentieth Century Fox Film Corporation   1966-08-24
#
#        vote_count  vote_average  release_year   weeknd  friday
# 0            5562           6.5          2015  weekday       0
# 1            6185           7.1          2015  weekday       0
# 2            2480           6.3          2015  weekday       0
# 3            5292           7.5          2015  weekday       0
# 4            2947           7.3          2015  weekday       0
# ...           ...           ...           ...      ...     ...
# 10822          74           7.5          1966  weekday       0
# 10828          46           6.3          1966  weekday       0
# 10829          36           6.9          1966  weekend       0
# 10835          28           7.0          1966  weekday       0
# 10848          42           6.7          1966  weekday       0
#
# [3678 rows x 17 columns]

# %%
movie[['friday','popularity']].corr()
# Out:
#               friday  popularity
# friday      1.000000   -0.171462
# popularity -0.171462    1.000000

# %%
movie['weeknd'] = enc.fit_transform(movie['weeknd'].values)

# %%
movie[['weeknd','popularity']].corr()
# Out:
#              weeknd  popularity
# weeknd      1.00000    -0.01479
# popularity -0.01479     1.00000

# %%
def weekday(date):
    temp = pd.Timestamp(date)
    return temp.day_name()

# %%
movie['weekday'] = movie['release_date'].apply(weekday)

# %%
movie['weekday'].value_counts()
# Out:
# Friday       1594
# Thursday      752
# Wednesday     627
# Tuesday       258
# Monday        171
# Saturday      145
# Sunday        131
# Name: weekday, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# keywords                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# dtype: int64

# %%
movie['director'] = enc.fit_transform(movie['director'].values)

# %%
movie[['director','revenue']].corr()
# Out:
#           director   revenue
# director  1.000000 -0.011834
# revenue  -0.011834  1.000000

# %%
movie['weekday'] = enc.fit_transform(movie['weekday'].values)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
y=movie['popularity']

# %%
X = movie[['budget','vote_count','vote_average','weeknd','friday','revenue']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
min_max_scaler =MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_test_minmax = min_max_scaler.transform(X_test)

# %%
lr.fit(X_train_minmax,y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test_minmax)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.4349718470751823
# MSE: 1.0761193040712493
# RMSE: 1.0373617035881213

# %%
coeffecients = pd.DataFrame(lr.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#               Coeffecient
# budget           0.896509
# vote_count      12.253553
# vote_average     0.381627
# weeknd          -0.010438
# friday          -0.038421
# revenue         -0.623573

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
rg = Ridge(random_state=42)

# %%
rg.fit(X_train_minmax,y_train)
# Out:
# Ridge(random_state=42)

# %%
rg_pred = rg.predict(X_test_minmax)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, rg_pred))
print('MSE:', metrics.mean_squared_error(y_test, rg_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rg_pred)))
# Out:
# MAE: 0.4358870266114403
# MSE: 1.0673090205958042
# RMSE: 1.0331064904431702

# %%
grid = dict()
grid['alpha'] = np.arange(0, 1, 0.01)
grid['tol']=[.001,.00001,.002,.0001,.0002]
grid['fit_intercept']=[True,False]
grid['solver']=['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# %%
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.model_selection import RepeatedKFold

# %%
rg_tune=Ridge(random_state=42)

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=42)

# %%
rg_model = GridSearchCV(rg_tune,param_grid=grid ,cv=cv, scoring='neg_mean_squared_error',n_jobs=-1)

# %%
rg_result = rg_model.fit(X_train_minmax, y_train)

# %%
rg_result.best_score_
# Out:
# -0.8250244391857638

# %%
rg_result.best_params_
# Out:
# {'alpha': 0.25, 'fit_intercept': True, 'solver': 'saga', 'tol': 0.001}

# %%
#print(rg_model.cv_results_['mean_score_time'][rg_model.best_index_], rg_model.cv_results_['std_score_time'][rg_model.best_index_])

# %%
rg_ = Ridge(alpha=.25,fit_intercept=True,solver='saga',tol=.001,random_state=42)

# %%
results = cross_validate(rg_, X_train_minmax,  y_train,return_train_score = True, cv  = cv, scoring='neg_mean_squared_error')

# %%
print(results['test_score'].mean())
# Out:
# -0.8250244391857638
